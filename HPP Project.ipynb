# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("housing.csv")

# %%
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dataset.dropna(inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=dataset.drop(['median_house_value'],axis=1)
y=dataset['median_house_value']

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(x['ocean_proximity'])

x['ocean_proximity'] = le.transform(x['ocean_proximity'])

x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  ocean_proximity
# 0           322.0       126.0         8.3252                3
# 1          2401.0      1138.0         8.3014                3
# 2           496.0       177.0         7.2574                3
# 3           558.0       219.0         5.6431                3
# 4           565.0       259.0         3.8462                3
# ...           ...         ...            ...              ...
# 20635       845.0       330.0         1.5603                1
# 20636       356.0       114.0         2.5568                1
# 20637      1007.0       433.0         1.7000                1
# 20638       741.0       349.0         1.8672                1
# 20639      1387.0       530.0         2.3886                1
#
# [20433 rows x 9 columns]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  ocean_proximity
# 0           322.0       126.0         8.3252                3
# 1          2401.0      1138.0         8.3014                3
# 2           496.0       177.0         7.2574                3
# 3           558.0       219.0         5.6431                3
# 4           565.0       259.0         3.8462                3
# ...           ...         ...            ...              ...
# 20635       845.0       330.0         1.5603                1
# 20636       356.0       114.0         2.5568                1
# 20637      1007.0       433.0         1.7000                1
# 20638       741.0       349.0         1.8672                1
# 20639      1387.0       530.0         2.3886                1
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2100     -119.76     36.75                35.0       2347.0           526.0
# 20586    -122.03     38.69                23.0       1796.0           380.0
# 7849     -118.17     33.89                11.0       3605.0           880.0
# 4631     -118.30     34.06                20.0       1782.0           896.0
# 20263    -119.19     34.21                27.0       1887.0           487.0
# ...          ...       ...                 ...          ...             ...
# 19264    -122.73     38.44                35.0       1120.0           297.0
# 20414    -118.85     34.18                11.0       5873.0          1455.0
# 5376     -118.39     34.04                52.0       1492.0           277.0
# 10020    -121.16     39.18                14.0       1006.0           187.0
# 4102     -118.39     34.14                19.0       5076.0          1034.0
#
#        population  households  median_income  ocean_proximity
# 2100       1676.0       481.0         1.6548                1
# 20586       939.0       330.0         2.7955                1
# 7849       3637.0       873.0         2.6328                0
# 4631       1749.0       823.0         2.2094                0
# 20263      1339.0       428.0         2.9185                4
# ...           ...         ...            ...              ...
# 19264       659.0       274.0         2.3824                0
# 20414      3089.0      1365.0         3.5504                0
# 5376        666.0       289.0         4.7386                0
# 10020       462.0       185.0         3.1042                1
# 4102       2021.0       960.0         5.5683                0
#
# [16346 rows x 9 columns]

# %%
y_train
# Out:
# 2100      49400.0
# 20586     96300.0
# 7849     160700.0
# 4631      75000.0
# 20263    224500.0
#            ...
# 19264    145000.0
# 20414    173800.0
# 5376     340400.0
# 10020    152000.0
# 4102     309200.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16108    -122.50     37.74                40.0       2310.0           445.0
# 10059    -120.94     39.32                14.0       3120.0           595.0
# 20190    -119.17     34.26                10.0       3654.0           541.0
# 13411    -117.46     34.07                19.0       3155.0           572.0
# 18448    -121.81     37.23                16.0       1674.0           281.0
# ...          ...       ...                 ...          ...             ...
# 13846    -117.35     34.50                10.0       2163.0           392.0
# 534      -122.27     37.78                45.0       1169.0           263.0
# 9778     -121.13     36.21                27.0       1476.0           352.0
# 1532     -122.05     37.90                24.0       4125.0          1020.0
# 2650     -124.09     40.44                38.0       2220.0           426.0
#
#        population  households  median_income  ocean_proximity
# 16108      1266.0       490.0         3.7969                4
# 10059      1569.0       556.0         3.5385                1
# 20190      1638.0       551.0         6.1885                4
# 13411      2482.0       642.0         2.9973                1
# 18448       850.0       254.0         5.3157                0
# ...           ...         ...            ...              ...
# 13846      1174.0       362.0         3.3750                1
# 534         723.0       286.0         3.9444                3
# 9778       1156.0       358.0         3.1929                0
# 1532       1699.0       873.0         2.9526                3
# 2650       1041.0       401.0         2.3947                0
#
# [4087 rows x 9 columns]

# %%
y_test
# Out:
# 16108    297800.0
# 10059    157400.0
# 20190    267300.0
# 13411    113400.0
# 18448    253300.0
#            ...
# 13846     98000.0
# 534      212900.0
# 9778     137900.0
# 1532     271000.0
# 2650      70500.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
train_dataset=x_train.join(y_train)

# %%
train_dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2100     -119.76     36.75                35.0       2347.0           526.0
# 20586    -122.03     38.69                23.0       1796.0           380.0
# 7849     -118.17     33.89                11.0       3605.0           880.0
# 4631     -118.30     34.06                20.0       1782.0           896.0
# 20263    -119.19     34.21                27.0       1887.0           487.0
# ...          ...       ...                 ...          ...             ...
# 19264    -122.73     38.44                35.0       1120.0           297.0
# 20414    -118.85     34.18                11.0       5873.0          1455.0
# 5376     -118.39     34.04                52.0       1492.0           277.0
# 10020    -121.16     39.18                14.0       1006.0           187.0
# 4102     -118.39     34.14                19.0       5076.0          1034.0
#
#        population  households  median_income  ocean_proximity  \
# 2100       1676.0       481.0         1.6548                1
# 20586       939.0       330.0         2.7955                1
# 7849       3637.0       873.0         2.6328                0
# 4631       1749.0       823.0         2.2094                0
# 20263      1339.0       428.0         2.9185                4
# ...           ...         ...            ...              ...
# 19264       659.0       274.0         2.3824                0
# 20414      3089.0      1365.0         3.5504                0
# 5376        666.0       289.0         4.7386                0
# 10020       462.0       185.0         3.1042                1
# 4102       2021.0       960.0         5.5683                0
#
#        median_house_value
# 2100              49400.0
# 20586             96300.0
# 7849             160700.0
# 4631              75000.0
# 20263            224500.0
# ...                   ...
# 19264            145000.0
# 20414            173800.0
# 5376             340400.0
# 10020            152000.0
# 4102             309200.0
#
# [16346 rows x 10 columns]

# %%
train_dataset.hist(figsize=(15,9))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'ocean_proximity'}>],
#        [<AxesSubplot:title={'center':'median_house_value'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
train_dataset.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925442           -0.105929     0.038657
# latitude            -0.925442  1.000000            0.010737    -0.032431
# housing_median_age  -0.105929  0.010737            1.000000    -0.361249
# total_rooms          0.038657 -0.032431           -0.361249     1.000000
# total_bedrooms       0.063683 -0.063409           -0.322069     0.930021
# population           0.095736 -0.105873           -0.296371     0.859434
# households           0.052355 -0.068537           -0.304115     0.922558
# median_income       -0.015616 -0.079660           -0.119225     0.200985
# ocean_proximity     -0.284128  0.194689            0.114276    -0.011819
# median_house_value  -0.042645 -0.146909            0.105900     0.136915
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063683    0.095736    0.052355      -0.015616
# latitude                 -0.063409   -0.105873   -0.068537      -0.079660
# housing_median_age       -0.322069   -0.296371   -0.304115      -0.119225
# total_rooms               0.930021    0.859434    0.922558       0.200985
# total_bedrooms            1.000000    0.879924    0.982528      -0.007390
# population                0.879924    1.000000    0.906451       0.006618
# households                0.982528    0.906451    1.000000       0.014200
# median_income            -0.007390    0.006618    0.014200       1.000000
# ocean_proximity          -0.012406   -0.064883   -0.015984      -0.014493
# median_house_value        0.051989   -0.022660    0.066864       0.687136
#
#                     ocean_proximity  median_house_value
# longitude                 -0.284128           -0.042645
# latitude                   0.194689           -0.146909
# housing_median_age         0.114276            0.105900
# total_rooms               -0.011819            0.136915
# total_bedrooms            -0.012406            0.051989
# population                -0.064883           -0.022660
# households                -0.015984            0.066864
# median_income             -0.014493            0.687136
# ocean_proximity            1.000000            0.077340
# median_house_value         0.077340            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_dataset.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
train_dataset['total_rooms']=np.log(train_dataset['total_rooms'] + 1)
train_dataset['total_bedrooms']=np.log(train_dataset['total_bedrooms'] + 1)
train_dataset['population']=np.log(train_dataset['population'] + 1)
train_dataset['households']=np.log(train_dataset['households'] + 1)

# %%
train_dataset.hist(figsize=(15,8))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'ocean_proximity'}>],
#        [<AxesSubplot:title={'center':'median_house_value'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
train_dataset.ocean_proximity.value_counts()
# Out:
# 0    7185
# 1    5219
# 4    2143
# 3    1798
# 2       1
# Name: ocean_proximity, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude',y='longitude' , data=train_dataset, hue='median_house_value',palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
train_dataset['bedroom_ratio']=train_dataset['total_bedrooms']/train_dataset['total_rooms']
train_dataset['household_rooms']=train_dataset['total_rooms']/train_dataset['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_dataset.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2100     -119.76     36.75                35.0       2347.0           526.0
# 20586    -122.03     38.69                23.0       1796.0           380.0
# 7849     -118.17     33.89                11.0       3605.0           880.0
# 4631     -118.30     34.06                20.0       1782.0           896.0
# 20263    -119.19     34.21                27.0       1887.0           487.0
# ...          ...       ...                 ...          ...             ...
# 19264    -122.73     38.44                35.0       1120.0           297.0
# 20414    -118.85     34.18                11.0       5873.0          1455.0
# 5376     -118.39     34.04                52.0       1492.0           277.0
# 10020    -121.16     39.18                14.0       1006.0           187.0
# 4102     -118.39     34.14                19.0       5076.0          1034.0
#
#        population  households  median_income  ocean_proximity
# 2100       1676.0       481.0         1.6548                1
# 20586       939.0       330.0         2.7955                1
# 7849       3637.0       873.0         2.6328                0
# 4631       1749.0       823.0         2.2094                0
# 20263      1339.0       428.0         2.9185                4
# ...           ...         ...            ...              ...
# 19264       659.0       274.0         2.3824                0
# 20414      3089.0      1365.0         3.5504                0
# 5376        666.0       289.0         4.7386                0
# 10020       462.0       185.0         3.1042                1
# 4102       2021.0       960.0         5.5683                0
#
# [16346 rows x 9 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(x_train['ocean_proximity'])

x_train['ocean_proximity'] = le.transform(x_train['ocean_proximity'])

x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2100     -119.76     36.75                35.0       2347.0           526.0
# 20586    -122.03     38.69                23.0       1796.0           380.0
# 7849     -118.17     33.89                11.0       3605.0           880.0
# 4631     -118.30     34.06                20.0       1782.0           896.0
# 20263    -119.19     34.21                27.0       1887.0           487.0
# ...          ...       ...                 ...          ...             ...
# 19264    -122.73     38.44                35.0       1120.0           297.0
# 20414    -118.85     34.18                11.0       5873.0          1455.0
# 5376     -118.39     34.04                52.0       1492.0           277.0
# 10020    -121.16     39.18                14.0       1006.0           187.0
# 4102     -118.39     34.14                19.0       5076.0          1034.0
#
#        population  households  median_income  ocean_proximity
# 2100       1676.0       481.0         1.6548                1
# 20586       939.0       330.0         2.7955                1
# 7849       3637.0       873.0         2.6328                0
# 4631       1749.0       823.0         2.2094                0
# 20263      1339.0       428.0         2.9185                4
# ...           ...         ...            ...              ...
# 19264       659.0       274.0         2.3824                0
# 20414      3089.0      1365.0         3.5504                0
# 5376        666.0       289.0         4.7386                0
# 10020       462.0       185.0         3.1042                1
# 4102       2021.0       960.0         5.5683                0
#
# [16346 rows x 9 columns]

# %% [markdown]
# # linear regressor

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression() # this is the model
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([249287.8883293 ,  76836.88044365, 304537.78918412, ...,
#        212197.54120854, 224910.39728637, 148136.80842022])

# %%
# from sklearn.metrics import regressor_score
# regressor.score(x_test,y_test)
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_true=y_test, y_pred=y_pred, squared=False)

# %%
rmse
# Out:
# 70092.20084889738

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6374429069606568

# %% [markdown]
# # random forest regressor

# %%
# Fitting Random Forest Regression to the dataset
# import the regressor
from sklearn.ensemble import RandomForestRegressor

# create rf_regressor object
rf_regressor = RandomForestRegressor(n_estimators = 50, random_state = 0)

# fit the regressor with x and y data
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
rf_y_pred = rf_regressor.predict(x_test)
rf_y_pred
# Out:
# array([288156.  , 139362.  , 351922.08, ..., 158696.  , 199110.  ,
#         78352.  ])

# %%
# from sklearn.metrics import regressor_score
from sklearn.metrics import mean_squared_error

rf_rmse = mean_squared_error(y_true=y_test, y_pred=rf_y_pred, squared=False)
rf_rmse
# Out:
# 50239.14482607661

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6374429069606568

# %% [markdown]
# # xgboost regressor

# %%
import os

# %%
os.system("pip install xgboost")
# Out:
# 0

# %%
import xgboost as xgb

# %%
xg_regressor = xgb.XGBRegressor(n_estimators = 50, random_state=0)
xg_regressor.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=50, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=0, ...)

# %%
xg_y_pred=xg_regressor.predict(x_test)
xg_y_pred
# Out:
# array([242608.1  , 134462.56 , 319302.28 , ..., 159893.94 , 252322.4  ,
#         62395.074], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error

xg_rmse = mean_squared_error(y_true=y_test, y_pred=xg_y_pred, squared=False)
xg_rmse
# Out:
# 49187.536566629344

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6374429069606568

# %% [markdown]
# # save the model

# %%
import pickle

# %%
pickle.dump(rf_regressor,open('model_pickle.pkl','wb'))
